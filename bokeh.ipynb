# %%
import numpy as np
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# %%
output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="bca1e0b3-4cd4-4f1c-8dcc-30d79b86e116">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.sampledata.iris import flowers  # Dataset Iris déjà intégré
from bokeh.sampledata.autompg import autompg as df # Dataset Auto MPG

# %%
p = figure(width=400, height=400)
p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=0.5)
show(p)
# Out:
# ...
#   <div id="ed6e4827-df19-4f06-832c-d6061db3d095" data-root-id="p1046" style="display: contents;"></div>

# %%
x= figure(width= 400, height=400)
x.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], radius=.1, color="navy", alpha=0.5)
show(x)
# Out:
#   <div id="ddbf6f3a-9bd3-40f4-8087-43d72afd51ab" data-root-id="p1258" style="display: contents;"></div>

# %%
l = figure(width=400, height=400)
l.square([2,7, 4, 9, 6], [5, 8, 3, 7, 2], size=[5, 15, 5, 15, 15], color="blue", alpha=0.5)
show(l)
# Out:
# ...
#   <div id="a2141cdb-4ecf-48bf-9955-22b4fcaa34a3" data-root-id="p1382" style="display: contents;"></div>

# %% [markdown]
# je remarque que la premiere liste équivaut a laxe des abscisses "X" et la deuxieme liste équivaut a laxe des ordonnées "Y", les nombres correspondent aux coordonées et non a des indices

# %%
from bokeh.plotting import figure, show

p = figure()
p.circle(
    x=[1, 2, 3, 4, 5],
    y=[6, 7, 2, 4, 5],
    size=[10, 20, 30, 15, 25],  # Les tailles sont vectorisées ici
    color=["red", "blue", "green", "purple", "orange"]  # Couleurs vectorisées
)
show(p)
# Out:
# ...
#   <div id="f1303394-87c2-43b6-a5d3-b9bea2236af5" data-root-id="p1425" style="display: contents;"></div>

# %%
p.circle(x=10, y=10, size=20, color="navy")  # Applique "navy" à line_color et fill_color
show(p)
# Out:
# ...
#   <div id="f18fe30f-dd32-481f-abf6-344e5d47a0cd" data-root-id="p1425" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()

p = figure(title="Exemples de Markers avec Bokeh")

# Différents markers
p.circle(x=[1, 2, 3], y=[4, 5, 6], size=15, color="blue", legend_label="circle")
p.diamond(x=[1, 2, 3], y=[3, 4, 5], size=15, color="green", legend_label="diamond")
p.triangle(x=[1, 2, 3], y=[2, 3, 4], size=15, color="red", legend_label="triangle")
p.square(x=[1, 2, 3], y=[1, 2, 3], size=15, color="purple", legend_label="square")

p.legend.title = "Type de Marker"
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e645764d-0ff1-4bdc-85cd-87f5fd6f98f7">Loading BokehJS ...</span>
#     </div>
# ...
#   <div id="ba263b8d-997f-4768-a98a-3d85f3e7ddee" data-root-id="p1488" style="display: contents;"></div>

# %%
from bokeh.plotting import figure, show

p = figure(title="Exemple de line_color et fill_color")

# Un cercle avec contour noir et remplissage bleu
p.circle(x=1, y=1, size=50, line_color="black", fill_color="blue")

# Un autre cercle avec contour rouge et remplissage vert
p.circle(x=2, y=2, size=50, line_color="red", fill_color="green")

show(p)
# Out:
# ...
#   <div id="a8ce1f25-27ff-472a-9ecf-b53707ec28db" data-root-id="p1564" style="display: contents;"></div>

# %%
df.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70       1                ford torino

# %%
from bokeh.sampledata.glucose import data

# %%
data.head()
# Out:
#                       isig  glucose
# datetime
# 2010-03-24 09:51:00  22.59      258
# 2010-03-24 09:56:00  22.52      260
# 2010-03-24 10:01:00  22.23      258
# 2010-03-24 10:06:00  21.56      254
# 2010-03-24 10:11:00  20.79      246

# %%
week = data.loc['2010-10-01':'2010-10-08']
s= figure(x_axis_type= 'datetime', title='Glucose Range', height=350, width=800)
s.xgrid.grid_line_color=None
s.ygrid.grid_line_alpha=.5
s.xaxis.axis_label='Time'
s.yaxis.axis_label= 'Value'

s.line(week.index, week.glucose)

show(s)
# Out:
#   <div id="c03add3c-e048-410d-bc33-a428b699438d" data-root-id="p1620" style="display: contents;"></div>

# %%
# EXERCISE: Look at the AAPL data from bokeh.sampledata.stocks and create a line plot using it
from bokeh.sampledata.stocks import AAPL

# AAPL.keys()
# dict_keys(['date', 'open', 'high', 'low', 'close', 'volume', 'adj_close'])

dates = np.array(AAPL['date'], dtype=np.datetime64) # convert date strings to real datetimes
closes = np.array(AAPL['close'], dtype=np.float64)
x= figure(x_axis_type='datetime', title='AAPL', width= 800, height=400)
x.xaxis.axis_label='Time'
x.yaxis.axis_label='Value'

x.line(dates, closes)
show(x)
# Out:
#   <div id="c1a4e8a4-244e-4589-aae4-bafae514e8f5" data-root-id="p1678" style="display: contents;"></div>
